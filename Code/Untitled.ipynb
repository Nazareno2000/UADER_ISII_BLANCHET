# %%
print("numero de proyecto", variable)
print(variable + variable2)

print("primer pr
variable=1
print("primer proyecto")
variable=1
variable2=2
primer proyecto
+ variable2
print("numero de proyecto", variable)
print(variable + variable2)
numero de proyecto 1
3
oyecto")
variable=1
variable2=2
# Out:
# numero de proyecto 1
# 3

# %% [markdown]
# #Pude ya que debi correr la primera celda para que en la segunda me funcione"

# %% [markdown]
# #Reinicia el nucleo actual
# #interrumpt : te interrumpe la ejecucion
# #Reinicia el nucleo actual y borra todos los resultados
# #In[] muestra el numero de la celda

# %% [markdown]
# # Universidad Autónoma de Entre Ríos
# ## Facultad de Ciencia y Tecnología
# ### Sede Concepción del Uruguay
# Licenciatura en Sistema de Información:
# - Primer año
# - Segundo año
# - **Tercer** año
# - Cuarto año
# - Quinto año

# %% [markdown]
# ![imagen](data:image/jpeg;base64,...)

# %% [markdown]
# ![Figure_1.png](attachment:Figure_1.png)

# %% [markdown]
# Pude ingresar la imagen copiando y pegando la direccion en la celda
# Podes cambiar de orden con las flechas que aparecen arriba a la izq
# Se puede mezclar las celda con la opcion que aparece en edit merge above(arriba) merge below(abajo)

# %% [markdown]
# ![TestingPatrones.png](attachment:TestingPatrones.png)

# %% [markdown]
# ![TestingPatrones2.png](attachment:TestingPatrones2.png)

# %% [markdown]
# Patron bridge antes de mergear con la rama testing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Patron luego del merge
